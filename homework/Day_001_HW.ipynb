# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
"""
Homework-1:
Data : https://www.kaggle.com/zynicide/wine-reviews
侍酒師對各款紅酒口感的描述大數據

1. 你選的這組資料為何重要
   -- 這是一個有趣的議題，是否可以利用這數據去玩盲飲猜出酒莊年份並可進一歩分析顧客對一些酒的喜好去推薦適合他/她的酒款
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
   -- 資料數據是從www.winemag.com公佈的資料，zackthoutt利用網路爬蟲的方法從www.winemag.com公佈的資料取得
3. 蒐集而來的資料型態為何
   -- 有結構化的資(如:年份, 分數)，也有非結構化的資料(如:侍酒師對酒的描述)
4. 這組資料想解決的問題如何評估
   -- 首先必須先解析酒的描述種類及其強弱的量化把這些非結構的資料轉換成數據，再來評估Model
"""
# Out:
# '\nHomework-1:\nData : https://www.kaggle.com/zynicide/wine-reviews\n侍酒師對各款紅酒口感的描述大數據\n\n1. 你選的這組資料為何重要\n   -- 這是一個有趣的議題，是否可以利用這數據去玩盲飲猜出酒莊年份並可進一歩分析顧客對一些酒的喜好去推薦適合他/她的酒款\n2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)\n   -- 資料數據是從www.winemag.com公佈的資料，zackthoutt利用網路爬蟲的方法從www.winemag.com公佈的資料取得\n3. 蒐集而來的資料型態為何\n   -- 有結構化的資(如:年份, 分數)，也有非結構化的資料(如:侍酒師對酒的描述)\n4. 這組資料想解決的問題如何評估\n   -- 首先必須先解析酒的描述種類及其強弱的量化把這些非結構的資料轉換成數據，再來評估Model\n'

# %%
"""
Homework-2:
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
  -- 如果業績是以營業額的%來收取，提升營業額減少空車率及空車去載客的路程，分析不同時段不同區域的長短程載客率
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
  -- 從每日載客的GPS記錄，收費及滿意度問卷調查，進一歩提供APP/Webpage叫車服務來取得數據
3. 蒐集而來的資料型態為何
  -- 應可得到結構化可量化的數據來分析
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
  -- 驗證即Mode最佳化的指標 - Max(總營業額)/day(month)，如果有油料補貼(成本) Max(營業額-成本)
"""

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行 -- OK
    """
    mse = sum((y-yp)*(y-yp))/len(y)
    return mse

def mean_absolute_error(y, yp):
    
    mae = sum(abs(y-yp))/len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 164.341
# The Mean absolute error is 10.055
